# %% [markdown]
# ## This example is based on Microsoft Machine Learning example [Churn Prediction](https://docs.microsoft.com/en-us/azure/machine-learning/desktop-workbench/scenario-churn-prediction)
# This is a binary classification problem.  Download data [here](https://github.com/Azure/MachineLearningSamples-ChurnPrediction/tree/master/data).

# %%
import pandas as pd
import csv
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Read and clean raw data

# %%
df = pd.read_csv('../data/CATelcoCustomerChurnTrainingSample.csv')
df = df.drop_duplicates() 
df = df.drop('year', 1) 
df = df.drop('month', 1) 
df = df.fillna(0) 
df.head(20)
# Out:
#     age  annualincome  calldroprate  callfailurerate  callingnum  customerid  \
# 0    12        168147          0.06             0.00  4251078442           1
# 1    12        168147          0.06             0.00  4251078442           1
# 2    42         29047          0.05             0.01  4251043419           2
# 3    42         29047          0.05             0.01  4251043419           2
# 4    58         27076          0.07             0.02  4251055773           3
# 5    58         27076          0.07             0.02  4251055773           3
# 6    20        137977          0.05             0.03  4251042488           4
# 7    20        137977          0.05             0.03  4251042488           4
# 8    36        136006          0.07             0.00  4251073177           5
# 9    36        136006          0.07             0.00  4251073177           5
# 10   67        246906          0.05             0.01  4251023523           6
# 11   67        246906          0.05             0.01  4251023523           6
# 12   14        244935          0.07             0.02  4251055777           7
# 13   14        244935          0.07             0.02  4251055777           7
# 14   45        105835          0.05             0.03  4251045184           8
# 15   45        105835          0.05             0.03  4251045184           8
# 16   61        103864          0.07             0.00  4251031912           9
# 17   61        103864          0.07             0.00  4251031912           9
# 18   61        103864          0.07             0.00  4251031912           9
# 19   23        214765          0.06             0.01  4251042084          10
#
#    customersuspended               education  gender homeowner  ...    \
# 0                Yes  Bachelor or equivalent    Male       Yes  ...
# 1                Yes  Bachelor or equivalent    Male       Yes  ...
# 2                Yes  Bachelor or equivalent  Female       Yes  ...
# 3                Yes  Bachelor or equivalent  Female       Yes  ...
# 4                Yes    Master or equivalent  Female       Yes  ...
# 5                Yes    Master or equivalent  Female       Yes  ...
# 6                Yes       PhD or equivalent    Male        No  ...
# 7                Yes       PhD or equivalent    Male        No  ...
# 8                Yes    High School or below    Male       Yes  ...
# 9                Yes    High School or below    Male       Yes  ...
# 10               Yes    High School or below  Female       Yes  ...
# 11               Yes    High School or below  Female       Yes  ...
# 12               Yes    High School or below    Male       Yes  ...
# 13               Yes    High School or below    Male       Yes  ...
# 14               Yes    High School or below  Female       Yes  ...
# 15               Yes    High School or below  Female       Yes  ...
# 16               Yes  Bachelor or equivalent  Female       Yes  ...
# 17               Yes  Bachelor or equivalent  Female       Yes  ...
# 18               Yes  Bachelor or equivalent  Female       Yes  ...
# 19               Yes  Bachelor or equivalent    Male       Yes  ...
#
#    penaltytoswitch  state totalminsusedinlastmonth  unpaidbalance  \
# 0              371     WA                       15             19
# 1              371     WA                       15             19
# 2               43     WI                      212             34
# 3               43     WI                      212             34
# 4              403     KS                      216            144
# 5              403     KS                      216            144
# 6               76     KY                      412            159
# 7               76     KY                      412            159
# 8              436     ND                      416             19
# 9              436     ND                      416             19
# 10             108     OK                      113             34
# 11             108     OK                      113             34
# 12             468     AZ                      116            144
# 13             468     AZ                      116            144
# 14             141     CA                      313            159
# 15             141     CA                      313            159
# 16               1     MI                      316             19
# 17               1     MI                      316             19
# 18               1     MI                      316             19
# 19             173     MN                       13             34
#
#     usesinternetservice  usesvoiceservice percentagecalloutsidenetwork  \
# 0                    No                No                         0.82
# 1                    No                No                         0.82
# 2                    No               Yes                         0.27
# 3                    No               Yes                         0.27
# 4                    No                No                         0.48
# 5                    No                No                         0.48
# 6                   Yes                No                         0.94
# 7                   Yes                No                         0.94
# 8                    No                No                         0.15
# 9                    No                No                         0.15
# 10                   No                No                         0.61
# 11                   No                No                         0.61
# 12                   No                No                         0.82
# 13                   No                No                         0.82
# 14                   No                No                         0.27
# 15                   No                No                         0.27
# 16                   No                No                         0.48
# 17                   No                No                         0.48
# 18                   No                No                         0.48
# 19                   No                No                         0.94
#
#     totalcallduration avgcallduration  churn
# 0                5971             663      0
# 1                3981             995      0
# 2                7379             737      0
# 3                1729             432      0
# 4                3122             624      0
# 5                2769             553      0
# 6                 834             834      0
# 7                5868             838      0
# 8                1886             628      0
# 9                2602             867      0
# 10               2737             391      0
# 11               5845             835      0
# 12               3342             557      0
# 13               2428             809      0
# 14               2446             815      0
# 15               4882             813      0
# 16               2065             516      0
# 17               2802             560      0
# 18                268             268      0
# 19               3022             755      1
#
# [20 rows x 27 columns]

# %% [markdown]
# ## Convert text features to numeric indices

# %%
columns_to_encode = list(df.select_dtypes(include=['category','object']))
for column_to_encode in columns_to_encode:
    le = LabelEncoder()
    df[column_to_encode] = le.fit_transform(df[column_to_encode])
df.head(20)
# Out:
#     age  annualincome  calldroprate  callfailurerate  callingnum  customerid  \
# 0    12        168147          0.06             0.00  4251078442           1
# 1    12        168147          0.06             0.00  4251078442           1
# 2    42         29047          0.05             0.01  4251043419           2
# 3    42         29047          0.05             0.01  4251043419           2
# 4    58         27076          0.07             0.02  4251055773           3
# 5    58         27076          0.07             0.02  4251055773           3
# 6    20        137977          0.05             0.03  4251042488           4
# 7    20        137977          0.05             0.03  4251042488           4
# 8    36        136006          0.07             0.00  4251073177           5
# 9    36        136006          0.07             0.00  4251073177           5
# 10   67        246906          0.05             0.01  4251023523           6
# 11   67        246906          0.05             0.01  4251023523           6
# 12   14        244935          0.07             0.02  4251055777           7
# 13   14        244935          0.07             0.02  4251055777           7
# 14   45        105835          0.05             0.03  4251045184           8
# 15   45        105835          0.05             0.03  4251045184           8
# 16   61        103864          0.07             0.00  4251031912           9
# 17   61        103864          0.07             0.00  4251031912           9
# 18   61        103864          0.07             0.00  4251031912           9
# 19   23        214765          0.06             0.01  4251042084          10
#
#     customersuspended  education  gender  homeowner  ...    penaltytoswitch  \
# 0                   1          0       1          1  ...                371
# 1                   1          0       1          1  ...                371
# 2                   1          0       0          1  ...                 43
# 3                   1          0       0          1  ...                 43
# 4                   1          2       0          1  ...                403
# 5                   1          2       0          1  ...                403
# 6                   1          3       1          0  ...                 76
# 7                   1          3       1          0  ...                 76
# 8                   1          1       1          1  ...                436
# 9                   1          1       1          1  ...                436
# 10                  1          1       0          1  ...                108
# 11                  1          1       0          1  ...                108
# 12                  1          1       1          1  ...                468
# 13                  1          1       1          1  ...                468
# 14                  1          1       0          1  ...                141
# 15                  1          1       0          1  ...                141
# 16                  1          0       0          1  ...                  1
# 17                  1          0       0          1  ...                  1
# 18                  1          0       0          1  ...                  1
# 19                  1          0       1          1  ...                173
#
#     state  totalminsusedinlastmonth  unpaidbalance  usesinternetservice  \
# 0      46                        15             19                    0
# 1      46                        15             19                    0
# 2      47                       212             34                    0
# 3      47                       212             34                    0
# 4      15                       216            144                    0
# 5      15                       216            144                    0
# 6      16                       412            159                    1
# 7      16                       412            159                    1
# 8      27                       416             19                    0
# 9      27                       416             19                    0
# 10     35                       113             34                    0
# 11     35                       113             34                    0
# 12      3                       116            144                    0
# 13      3                       116            144                    0
# 14      4                       313            159                    0
# 15      4                       313            159                    0
# 16     21                       316             19                    0
# 17     21                       316             19                    0
# 18     21                       316             19                    0
# 19     22                        13             34                    0
#
#     usesvoiceservice  percentagecalloutsidenetwork  totalcallduration  \
# 0                  0                          0.82               5971
# 1                  0                          0.82               3981
# 2                  1                          0.27               7379
# 3                  1                          0.27               1729
# 4                  0                          0.48               3122
# 5                  0                          0.48               2769
# 6                  0                          0.94                834
# 7                  0                          0.94               5868
# 8                  0                          0.15               1886
# 9                  0                          0.15               2602
# 10                 0                          0.61               2737
# 11                 0                          0.61               5845
# 12                 0                          0.82               3342
# 13                 0                          0.82               2428
# 14                 0                          0.27               2446
# 15                 0                          0.27               4882
# 16                 0                          0.48               2065
# 17                 0                          0.48               2802
# 18                 0                          0.48                268
# 19                 0                          0.94               3022
#
#     avgcallduration  churn
# 0               663      0
# 1               995      0
# 2               737      0
# 3               432      0
# 4               624      0
# 5               553      0
# 6               834      0
# 7               838      0
# 8               628      0
# 9               867      0
# 10              391      0
# 11              835      0
# 12              557      0
# 13              809      0
# 14              815      0
# 15              813      0
# 16              516      0
# 17              560      0
# 18              268      0
# 19              755      1
#
# [20 rows x 27 columns]

# %% [markdown]
# ## Split data into training and test data sets

# %%
train, test = train_test_split(df, random_state = 42, test_size = 0.3)

target = train['churn'].values
train = train.drop('churn', 1)

expected = test['churn'].values
test = test.drop('churn', 1)

train.head(20)
# Out:
#        age  annualincome  calldroprate  callfailurerate  callingnum  \
# 17211   75        152283          0.03             0.00  4251048333
# 18597   65        168961          0.02             0.01  4251088692
# 15968   50        138023          0.05             0.02  4251020038
# 7285    77        239904          0.06             0.02  4251048206
# 8214    59        133945          0.03             0.02  4251097907
# 3813    46         71623          0.07             0.03  4251087087
# 796     57        127008          0.07             0.02  4251083915
# 10733   19        119907          0.01             0.03  4251031078
# 18075   35        241912          0.03             0.00  4251086980
# 8423    14        221484          0.00             0.03  4251093150
# 9315    18        235527          0.06             0.02  4251015868
# 2619    15        148188          0.01             0.01  4251061051
# 15981   37        216782          0.04             0.02  4251060608
# 20364   36        192440          0.07             0.02  4251057459
# 1748    27        121639          0.01             0.00  4251083431
# 16727   44        213937          0.03             0.00  4251025772
# 16316   17         76376          0.07             0.00  4251061968
# 5309    28        152255          0.07             0.00  4251065266
# 1122    28        185810          0.04             0.02   985409086
# 3101    50        239348          0.05             0.01  4251072114
#
#        customerid  customersuspended  education  gender  homeowner  \
# 17211        8010                  1          0       0          1
# 18597        8652                  1          1       1          1
# 15968        7430                  1          0       1          1
# 7285         3382                  1          0       1          1
# 8214         3815                  1          1       1          1
# 3813         1771                  1          0       1          0
# 796           371                  1          1       1          1
# 10733        4993                  1          2       0          1
# 18075        8411                  1          1       1          0
# 8423         3913                  1          1       1          1
# 9315         4326                  1          2       1          1
# 2619         1217                  1          2       0          1
# 15981        7436                  1          1       1          1
# 20364        9475                  1          1       0          1
# 1748          808                  1          1       0          1
# 16727        7782                  1          0       1          1
# 16316        7593                  1          1       1          1
# 5309         2461                  1          1       1          1
# 1122          520                  1          1       1          1
# 3101         1439                  1          1       1          0
#
#             ...         occupation  penaltytoswitch  state  \
# 17211       ...                  2              471     24
# 18597       ...                  1              259     36
# 15968       ...                  2              472     40
# 7285        ...                  0              429     43
# 8214        ...                  0              227     29
# 3813        ...                  0                3     40
# 796         ...                  1              210     28
# 10733       ...                  1              426     35
# 18075       ...                  2              429     24
# 8423        ...                  1              322     43
# 9315        ...                  2              412     15
# 2619        ...                  0              485     17
# 15981       ...                  0              209     31
# 20364       ...                  0              100      5
# 1748        ...                  1              167     11
# 16727       ...                  2              307     45
# 16316       ...                  0              300      6
# 5309        ...                  1              235     27
# 1122        ...                  1              479     25
# 3101        ...                  2               98     40
#
#        totalminsusedinlastmonth  unpaidbalance  usesinternetservice  \
# 17211                       162            184                    0
# 18597                       142            144                    0
# 15968                       294             14                    0
# 7285                         24            228                    0
# 8214                         95            229                    0
# 3813                        284             70                    0
# 796                         168             65                    0
# 10733                       368            142                    1
# 18075                        16              6                    0
# 8423                        410            103                    0
# 9315                        469              9                    0
# 2619                        299            201                    0
# 15981                       392             29                    0
# 20364                       344             12                    0
# 1748                        338            170                    0
# 16727                       439            191                    0
# 16316                        16             68                    0
# 5309                        389            188                    0
# 1122                        494            173                    0
# 3101                         33             74                    0
#
#        usesvoiceservice  percentagecalloutsidenetwork  totalcallduration  \
# 17211                 0                          0.12               1664
# 18597                 0                          0.03               7712
# 15968                 0                          0.37               3864
# 7285                  0                          0.91               4372
# 8214                  0                          0.28                 52
# 3813                  0                          0.58               2690
# 796                   0                          0.55               6064
# 10733                 1                          0.51               1664
# 18075                 0                          0.87               2063
# 8423                  0                          0.97               4105
# 9315                  0                          0.91               1765
# 2619                  0                          0.80               2512
# 15981                 0                          0.16               2894
# 20364                 0                          0.17               1179
# 1748                  1                          0.18               3318
# 16727                 1                          0.36               2775
# 16316                 0                          0.00               1685
# 5309                  1                          0.73               2740
# 1122                  0                          0.12               4222
# 3101                  0                          0.85               4781
#
#        avgcallduration
# 17211              832
# 18597              771
# 15968              644
# 7285               624
# 8214                52
# 3813               538
# 796                758
# 10733              416
# 18075              515
# 8423               586
# 9315               882
# 2619               628
# 15981              578
# 20364             1179
# 1748               553
# 16727              693
# 16316              842
# 5309               391
# 1122               603
# 3101               597
#
# [20 rows x 26 columns]

# %% [markdown]
# ## Train a decision tree model

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(train, target)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %% [markdown]
# ## Evaluate the model

# %%
predicted = model.predict(test)

print(roc_auc_score(expected, predicted))
# Out:
# 0.828096765593
